# %%
#TODO: Make plotting in a circle work
import numpy as np
import matplotlib.pyplot as plt
import cmath
plt.rc('text', usetex=True)

# %%
#how to plot in a circle?
#Figuring out how to plot a circle may be the bigger problem
#it's still casting the complex values to real ones

complex_exp_vectorized = np.vectorize(cmath.exp)
x = np.linspace(-10,10,1000)
fig,(ax1,ax2) = plt.subplots(1,2)
ax1.plot(x,np.exp(-np.square(x)))
ax1.set_title(r"$e^{-x^2}$")
ax2.plot(x,complex_exp_vectorized(-1j*np.square(x)))
ax2.set_title(r"$e^{-ix^2}$")
plt.show()
# Out:
# C:\Users\donte\Anaconda3\lib\site-packages\numpy\core\numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
